# %% [markdown]
# # NumPy and Image Assessment
#
# **COMPLETE THE TASKS IN BOLD BELOW.**

# %% [markdown]
# **TASK: Import NumPy**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **TASK: Create a 5 by 5 array where every number is a 10**

# %%
np.full((5,5),10.)
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %% [markdown]
# **TASK: Run the cell below to create an array of random numbers and see if you can figure out how it works.**

# %%
# %matplotlib inline
arr1 = np.random.rand(128,128)
plt.imshow(arr1,cmap='gray')

# %% [markdown]
# **TASK: What are the largest and smalled values in this array?**

# %%
arr1.max()
# Out:
# 0.9999859986635388

# %%
arr1.min()
# Out:
# 3.060729304060761e-05

# %% [markdown]
# **TASK: Use PIL and matplotlib to read and display the ../DATA/00-puppy.jpg image.**

# %%
from PIL import Image
image=Image.open("GDG.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x2037EA34580>

# %% [markdown]
# **TASK: Convert the image to a NumPy Array**

# %%
pic_arr=np.asarray(image)
pic_arr.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# **FINAL TASK: Use slicing to set the RED and GREEN channels of the picture to 0, then use imshow() to show the isolated blue channel**

# %%
import matplotlib.pyplot as plt 
copy_p=pic_arr.copy()
copy_p[:,:,1:3]= 0
plt.imshow(copy_p)

# %%
import matplotlib.pyplot as plt 
copy_p=pic_arr.copy()
copy_p[:,:,[0,2]]= 0
plt.imshow(copy_p)

# %%
import matplotlib.pyplot as plt 
copy_p=pic_arr.copy()
copy_p[:,:,0:2]= 0
plt.imshow(copy_p)

# %% [markdown]
# ### list can store multiple types
# ### numpy array can only store one type  , it faster than list providing more functionality (arithmatic) and vectorization
# ### numpy array consume less memory

# %% [markdown]
# ## Great Job!

# %% [markdown]
# ----
