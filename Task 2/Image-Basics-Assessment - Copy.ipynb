# %% [markdown]
# Try Do your best without using the Soultions

# %% [markdown]
# # Image Basics Assessment
#
# ## Complete the Tasks in bold below.

# %% [markdown]
# ----------
# #### TASK: Open the *any* image from the  folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

# %%
img = Image.open("logman.jpg")
plt.imshow(img)

# %% [markdown]
# ### Open image with CV2

# %%
imgCV = cv2.imread("logman.jpg")
plt.imshow(imgCV)

# %%
imgCVT= cv2.cvtColor(imgCV, cv2.COLOR_BGR2RGB)
plt.imshow(imgCVT)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
img_arr = np.asarray(img)
flip_img = cv2.flip(img_arr,-1)
plt.imshow(flip_img)

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the the adel emam face and display the image in the notebook.

# %%
from turtle import color

imgCVT_copy=imgCVT.copy()
cv2.rectangle(imgCVT_copy, pt1=(100,250), pt2=(300,0), color=(255,0,0), thickness=1)
plt.imshow(imgCVT_copy)

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image (over the another triangle if you can). The size and angle is up to you, but it should be a triangle (three sides) in any orientation. Note Triangle not exist Use Lines
# #### and Draw Circle inside the Triangle which is centroid where (cx,cy)=x1+x2+x3/3,y1+y2+y3/3 and you pick radius you want

# %%
imgCVT_Copy2=imgCVT.copy()
p1 = (300, 300)
p2 = (100, 400)
p3 = (0,300 )
cv2.line(imgCVT_Copy2, p1, p2, (255, 0, 0), 3)
cv2.line(imgCVT_Copy2, p2, p3, (255, 0, 0), 3)
cv2.line(imgCVT_Copy2, p1, p3, (255, 0, 0), 3)
centroid = ((p1[0]+p2[0]+p3[0])//3, (p1[1]+p2[1]+p3[1])//3)
cv2.circle(imgCVT_Copy2, centroid, 50, (0, 255, 0),thickness=2)
plt.imshow(imgCVT_Copy2)

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT ). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN. Session 3
# ### important Question tho

# %%
import cv2
import numpy as np
# Create a function based on a CV2 Event (Left button click)
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),100,(0,0,255),10)

# Open Image
img = cv2.imread("./funny.jpg")
# This names the window so we can reference it 
cv2.namedWindow(winname='dog')
# Connects the mouse button to our callback function
cv2.setMouseCallback('dog',draw_circle)

while True: #Runs forever until we break with Esc key on keyboard
    # Shows the image window
    cv2.imshow('dog',img)
    # EXPLANATION FOR THIS LINE OF CODE:
    # https://stackoverflow.com/questions/35372700/whats-0xff-for-in-cv2-waitkey1/39201163
    if cv2.waitKey(20) & 0xFF == 27:
        break
# Once script is done, its usually good practice to call this line
# It closes all windows (just in case you have multiple windows called)
cv2.destroyAllWindows()
